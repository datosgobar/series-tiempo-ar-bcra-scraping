# %% [markdown]
# # Genera metadatos del scraper "tce" (tcs de entidades financieras)

# %%
import pandas as pd
import json

# %% [markdown]
# ## Carga los archivos

# %%
df_dolar = pd.read_csv("datos/tce/tipos-cambio-dolar-entidades-financieras-series.csv")
df_euro = pd.read_csv("datos/tce/tipos-cambio-euro-entidades-financieras-series.csv")

with open("config_general.json", "r") as f:
    config = json.load(f)

# %% [markdown]
# ## Genera metadatos para el portapapeles

# %%
def get_metadata_from_title(title):
    """Genera metadatos de una serie a partir del nombre del campo."""
    coins = {
        "dolar": "usd",
        "euro": "eur"
    }
    
    if title == "indice_tiempo":
        return {"field_title": title, 
                "field_description": "Indice de tiempo.", 
                "field_id": ""}
    
    else:
        tc, ars, coin, entity, channel, flow, hour = title.split("_")

        # creo el id de la serie
        coin_iso = coins[coin]
        serie_id = "tc_{coin}_{entity}_{channel}{flow}{hour}".format(
            coin=coin_iso,
            entity=entity,
            channel=channel[0],
            flow=flow[0],
            hour=hour[:2]
        )
        
        # creo la descripción de la serie
        description = "Tipo de cambio ARS/{coin}. {entity}. {channel}. {flow}. {hour}.".format(
            coin=coin_iso.upper(),
            entity=config["tce"]["entities"][entity]["title"],
            channel=channel.title(),
            flow=flow.title(),
            hour=hour
        )
        
        return {"field_title": title, 
                "field_description": description, 
                "field_id": serie_id}

# %%
df_dolar_metadata = pd.DataFrame(map(get_metadata_from_title, df_dolar.columns))

# copiar y pegar en el catálogo
df_dolar_metadata.to_clipboard(index=False)

df_dolar_metadata
# Out:
#                                           field_title  \
# 0                                       indice_tiempo
# 1      tc_ars_dolar_hipotecario_mostrador_compra_11hs
# 2       tc_ars_dolar_hipotecario_mostrador_venta_11hs
# 3    tc_ars_dolar_hipotecario_electronico_compra_11hs
# 4     tc_ars_dolar_hipotecario_electronico_venta_11hs
# ..                                                ...
# 188           tc_ars_dolar_iol_electronico_venta_11hs
# 189          tc_ars_dolar_iol_electronico_compra_13hs
# 190           tc_ars_dolar_iol_electronico_venta_13hs
# 191          tc_ars_dolar_iol_electronico_compra_15hs
# 192           tc_ars_dolar_iol_electronico_venta_15hs
#
#                                      field_description  \
# 0                                    Indice de tiempo.
# 1    Tipo de cambio ARS/USD. Hipotecario. Mostrador...
# 2    Tipo de cambio ARS/USD. Hipotecario. Mostrador...
# 3    Tipo de cambio ARS/USD. Hipotecario. Electroni...
# 4    Tipo de cambio ARS/USD. Hipotecario. Electroni...
# ..                                                 ...
# 188  Tipo de cambio ARS/USD. Invertironline. Electr...
# 189  Tipo de cambio ARS/USD. Invertironline. Electr...
# 190  Tipo de cambio ARS/USD. Invertironline. Electr...
# 191  Tipo de cambio ARS/USD. Invertironline. Electr...
# 192  Tipo de cambio ARS/USD. Invertironline. Electr...
#
#                     field_id
# 0
# 1    tc_usd_hipotecario_mc11
# 2    tc_usd_hipotecario_mv11
# 3    tc_usd_hipotecario_ec11
# 4    tc_usd_hipotecario_ev11
# ..                       ...
# 188          tc_usd_iol_ev11
# 189          tc_usd_iol_ec13
# 190          tc_usd_iol_ev13
# 191          tc_usd_iol_ec15
# 192          tc_usd_iol_ev15
#
# [193 rows x 3 columns]

# %%
df_euro_metadata = pd.DataFrame(map(get_metadata_from_title, df_euro.columns))

# copiar y pegar en el catálogo
df_euro_metadata.to_clipboard(index=False)

df_euro_metadata
# Out:
#                                   field_title  \
# 0                               indice_tiempo
# 1   tc_ars_euro_galicia_mostrador_compra_11hs
# 2    tc_ars_euro_galicia_mostrador_venta_11hs
# 3   tc_ars_euro_galicia_mostrador_compra_13hs
# 4    tc_ars_euro_galicia_mostrador_venta_13hs
# ..                                        ...
# 92     tc_ars_euro_piano_mostrador_venta_11hs
# 93    tc_ars_euro_piano_mostrador_compra_13hs
# 94     tc_ars_euro_piano_mostrador_venta_13hs
# 95    tc_ars_euro_piano_mostrador_compra_15hs
# 96     tc_ars_euro_piano_mostrador_venta_15hs
#
#                                     field_description             field_id
# 0                                   Indice de tiempo.
# 1   Tipo de cambio ARS/EUR. Galicia. Mostrador. Co...  tc_eur_galicia_mc11
# 2   Tipo de cambio ARS/EUR. Galicia. Mostrador. Ve...  tc_eur_galicia_mv11
# 3   Tipo de cambio ARS/EUR. Galicia. Mostrador. Co...  tc_eur_galicia_mc13
# 4   Tipo de cambio ARS/EUR. Galicia. Mostrador. Ve...  tc_eur_galicia_mv13
# ..                                                ...                  ...
# 92  Tipo de cambio ARS/EUR. Piano. Mostrador. Vent...    tc_eur_piano_mv11
# 93  Tipo de cambio ARS/EUR. Piano. Mostrador. Comp...    tc_eur_piano_mc13
# 94  Tipo de cambio ARS/EUR. Piano. Mostrador. Vent...    tc_eur_piano_mv13
# 95  Tipo de cambio ARS/EUR. Piano. Mostrador. Comp...    tc_eur_piano_mc15
# 96  Tipo de cambio ARS/EUR. Piano. Mostrador. Vent...    tc_eur_piano_mv15
#
# [97 rows x 3 columns]

# %% [markdown]
# ## Imprime las series que no tengan ningún valor

# %%
# dolar
for col in df_dolar.columns:
    if all(pd.isnull(df_dolar[col])):
        print(col)

# %%
# euro
for col in df_euro.columns:
    if all(pd.isnull(df_euro[col])):
        print(col)
